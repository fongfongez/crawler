# %%
import pandas as pd
import csv

# %%
df = pd.read_csv("/workspaces/poetry-demo-test2/toDB/restaurant_Cleaned.csv")
df2 = pd.read_csv("/workspaces/poetry-demo-test2/toDB/restaurants.csv")

# %%
df2['st_address']
# Out:
# 0       大同區寧夏路060攤位號
# 1          大同區寧夏路46號
# 2        大同區寧夏路22之9號
# 3        大同區寧夏路010攤位
# 4        大同區寧夏夜市第89攤
#             ...
# 1972    士林區文林路340-1號
# 1973      士林區文林路341號
# 1974       士林區福德路20號
# 1975    士林區福德路12號14號
# 1976      士林區大東路158號
# Name: st_address, Length: 1977, dtype: object

# %%
df['st_address_origin'] = df2['st_address']
df
# Out:
#      nm_name                st_name_clean                      st_name  \
# 0       寧夏夜市                        方家雞肉飯                        方家雞肉飯
# 1       寧夏夜市                       圓環邊蚵仔煎                       圓環邊蚵仔煎
# 2       寧夏夜市                          李掌伯     李掌伯（原寧夏夜市里長伯麻辣臭豆腐鴨血蚵仔麵線）
# 3       寧夏夜市                         豬肝榮仔                         豬肝榮仔
# 4       寧夏夜市                         寧夏夜市                  寧夏夜市-爆漿脆皮魷魚
# ...      ...                          ...                          ...
# 1972    士林夜市  REEDS PIZZERIA & COFFEE 士林店  REEDS PIZZERIA & COFFEE 士林店
# 1973    士林夜市                         大塊牛排                   大塊牛排 - 士林店
# 1974    士林夜市                          海鮮粥                          海鮮粥
# 1975    士林夜市   Yiguo Ramen 라면 24H 異國無人拉麵店   Yiguo Ramen 라면 24H 異國無人拉麵店
# 1976    士林夜市                        圓通素食館                        圓通素食館
#
#      nm_city st_area st_road st_address  \
# 0        台北市     大同區     寧夏路    060攤位號
# ...

# %%
df.to_csv("/workspaces/poetry-demo-test2/toDB/restaurant_Cleaned.csv", header=True, index=None)
